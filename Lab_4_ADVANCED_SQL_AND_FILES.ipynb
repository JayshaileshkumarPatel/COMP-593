# %% [markdown]
# <a href="https://colab.research.google.com/github/JayshaileshkumarPatel/COMP-593/blob/main/Lab_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-789bb906-8543-43e6-a815-f4a96d615ef3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-789bb906-8543-43e6-a815-f4a96d615ef3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY (user_id) REFERENCES people (id),
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.

myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
query =  """INSERT INTO relationships (user_id, friend_id)
            VALUES (?, ?);"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
  user_id = randrange(1, 1001)

  friend_id = user_id
  while friend_id == user_id:
    friend_id = randrange(1, 1001) 
  
  args = (user_id, friend_id)
  #Execute the query
  myCursor.execute(query, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
import sqlite3
from pprint import pprint

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
#fp = open('report.txt', mode='')

#Complete the below query
query =  """SELECT people.name, relationships.friend_id From relationships
            LEFT JOIN people ON relationships.user_id = people.id
         """

myCursor.execute(query)
results = myCursor.fetchall()
#pprint(results)

myConnection.close()

for result in results:
  sentence = result[0] + " has " + str(result[1]) + " relationships.\n"
  print(sentence)

  #You will want to write the results to the file pointer here.
  #Use the newline character \n to create a line break in each write() statement.
  #Use print() statements as sanity checks if you are unsure of the integrity of your data.

#Don't forget to close the file pointer after you have finished!
# Out:
# Jonathan Alexander has 923 relationships.
#
# Amanda Ware has 6 relationships.
#
# Joseph Morris has 751 relationships.
#
# Cameron Fernandez has 775 relationships.
#
# Kyle Palmer has 370 relationships.
#
# Michele Williams has 673 relationships.
#
# Courtney Melendez has 773 relationships.
#
# Christine Webster has 599 relationships.
#
# Mrs. Kimberly Wall has 910 relationships.
#
# Sean Hoffman has 643 relationships.
#
# Lisa Bell has 457 relationships.
#
# David Smith has 838 relationships.
#
# Deborah Smith has 485 relationships.
#
# Kaitlyn Bautista has 445 relationships.
#
# Abigail Bailey has 627 relationships.
#
# Lisa Torres has 352 relationships.
#
# Joseph Ali has 354 relationships.
#
# Antonio Hughes has 269 relationships.
#
# Martin Lewis has 977 relationships.
#
# Lindsey Parker has 544 relationships.
#
# Andrew Tran has 338 relationships.
#
# Haley Rodriguez has 82 relationships.
#
# Isabella Miller has 812 relationships.
#
# Jessica Ward has 815 relationships.
#
# Denise Johnston has 17 relationships.
#
# Adam Newman has 710 relationships.
#
# Patrick Wallace has 605 relationships.
#
# Frank Hammond has 668 relationships.
#
# Mary Montes has 381 relationships.
#
# Adam Conner has 112 relationships.
#
# Antonio Hughes has 538 relationships.
#
# Andrew Tran has 79 relationships.
#
# Robert Reese has 480 relationships.
#
# Benjamin Boyle has 114 relationships.
#
# James Elliott has 882 relationships.
#
# Brent Simmons has 579 relationships.
#
# Lindsey Bell has 234 relationships.
#
# Jordan Terry has 194 relationships.
#
# Jon Little has 734 relationships.
#
# Timothy Johnson has 911 relationships.
#
# Alyssa Gilmore has 165 relationships.
#
# Michelle Gomez has 119 relationships.
#
# Tonya Hampton has 429 relationships.
#
# Scott Goodwin has 971 relationships.
#
# Matthew Clark has 950 relationships.
#
# Rebecca Murphy has 756 relationships.
#
# Seth Kidd has 908 relationships.
#
# Glenda Wilson has 330 relationships.
#
# Mary Martin has 744 relationships.
#
# Richard Cruz has 661 relationships.
#
# Donna Stewart has 486 relationships.
#
# Perry Bray has 396 relationships.
#
# Kristen Bowen has 290 relationships.
#
# Rachel Friedman has 3 relationships.
#
# Allison Walker has 852 relationships.
#
# Gerald Thornton has 676 relationships.
#
# Michelle Nunez has 951 relationships.
#
# Donald Franklin has 337 relationships.
#
# Mr. Roberto Rogers has 415 relationships.
#
# Dylan Harris has 343 relationships.
#
# Eric Anderson has 218 relationships.
#
# Jennifer Edwards has 342 relationships.
#
# Breanna Petersen has 243 relationships.
#
# Erika Lee has 422 relationships.
#
# Susan Wheeler has 389 relationships.
#
# Gregory Hall has 426 relationships.
#
# Robert Merritt has 249 relationships.
#
# Joseph Lewis has 924 relationships.
#
# Mary Lewis has 784 relationships.
#
# Mr. Martin Smith DDS has 115 relationships.
#
# Sean Hoffman has 709 relationships.
#
# Amy Marks has 483 relationships.
#
# Christine Vasquez has 412 relationships.
#
# Alexandra Lambert has 126 relationships.
#
# David Wright has 510 relationships.
#
# Raymond Stanley has 662 relationships.
#
# Brent Simmons has 591 relationships.
#
# Manuel Schultz has 713 relationships.
#
# Michelle Taylor has 762 relationships.
#
# Tyler Mullins has 335 relationships.
#
# Crystal Long has 819 relationships.
#
# Amanda Clark has 608 relationships.
#
# Brandon Williams has 526 relationships.
#
# Jessica Acosta has 99 relationships.
#
# Angela Williams has 1000 relationships.
#
# Christopher Baker has 504 relationships.
#
# Douglas Perez has 128 relationships.
#
# Lauren Floyd has 660 relationships.
#
# Calvin Cook has 101 relationships.
#
# Molly Davis has 451 relationships.
#
# Courtney Melendez has 422 relationships.
#
# Roger Harris has 819 relationships.
#
# Kimberly Garcia has 798 relationships.
#
# William Henderson has 75 relationships.
#
# Walter Snyder has 518 relationships.
#
# Mrs. Karen Jones has 257 relationships.
#
# Melissa Barnes has 484 relationships.
#
# Guy Olsen has 566 relationships.
#
# Penny Ruiz has 305 relationships.
#
# Jennifer Hansen has 908 relationships.
#
# Andrew Kim has 974 relationships.
#
# John Williams has 522 relationships.
#
# Molly Davis has 344 relationships.
#
# Christina Garcia has 805 relationships.
#
# Stephen Cunningham has 294 relationships.
#
# Matthew Clark has 517 relationships.
#
# Jesse Cook has 214 relationships.
#
# Carla Knight has 976 relationships.
#
# Christopher Medina has 486 relationships.
#
# Melissa Jones has 290 relationships.
#
# Jacob Jacobs has 201 relationships.
#
# Karl Wolfe has 378 relationships.
#
# Dr. Cheyenne Henry has 912 relationships.
#
# Eric Thomas has 460 relationships.
#
# Dr. Nicholas Ortiz MD has 536 relationships.
#
# Douglas Perez has 130 relationships.
#
# Michael Richmond has 45 relationships.
#
# Timothy Carlson has 604 relationships.
#
# Nicole Stewart has 825 relationships.
#
# Caleb Meadows has 229 relationships.
#
# Taylor Ward has 240 relationships.
#
# Rachel Harmon has 504 relationships.
#
# Alicia Townsend has 348 relationships.
#
# Catherine Weaver has 854 relationships.
#
# Eric Miller has 426 relationships.
#
# Francisco Smith has 163 relationships.
#
# Todd Maynard has 476 relationships.
#
# Gabriela Barrera has 674 relationships.
#
# Jennifer Lee has 60 relationships.
#
# Daisy Washington has 431 relationships.
#
# Brandon Martin has 530 relationships.
#
# Nichole Jones has 948 relationships.
#
# Steven Holmes has 767 relationships.
#
# Michael Hall has 859 relationships.
#
# Shelley Lewis has 48 relationships.
#
# Dana Allen has 132 relationships.
#
# Rebecca Ray has 168 relationships.
#
# Dale Garcia has 80 relationships.
#
# Logan Sanchez has 82 relationships.
#
# Michael Richmond has 732 relationships.
#
# Nicole Carrillo has 926 relationships.
#
# Andrew Bell has 949 relationships.
#
# Megan Moore has 382 relationships.
#
# Kevin Bates has 555 relationships.
#
# Cathy Robinson has 464 relationships.
#
# Sean Hoffman has 791 relationships.
#
# Stephanie Ward has 27 relationships.
#
# Jenna Zimmerman has 449 relationships.
#
# Alyssa Gilmore has 220 relationships.
#
# Jesse Cook has 229 relationships.
#
# Dr. John Collins has 464 relationships.
#
# David Carter has 202 relationships.
#
# Deborah Reyes has 97 relationships.
#
# Jessica Ward has 392 relationships.
#
# Mary Martin has 313 relationships.
#
# Amy Wilkerson has 124 relationships.
#
# Angel Miller has 850 relationships.
#
# Zachary Montgomery has 442 relationships.
#
# Logan Sanchez has 886 relationships.
#
# Colin Hurst has 75 relationships.
#
# Robert White has 327 relationships.
#
# Sara Brown has 711 relationships.
#
# Victor Barrett has 276 relationships.
#
# Jennifer Collins has 975 relationships.
#
# Mark Carter has 936 relationships.
#
# Carlos Ferguson has 672 relationships.
#
# Robert Torres has 1 relationships.
#
# Cole Middleton has 475 relationships.
#
# Brandi Love has 823 relationships.
#
# Melissa Escobar has 25 relationships.
#
# James Vasquez has 722 relationships.
#
# Eric Anderson has 538 relationships.
#
# Amber Smith has 320 relationships.
#
# Jeremy Ortiz has 663 relationships.
#
# Steven Salazar has 921 relationships.
#
# James Vasquez has 665 relationships.
#
# Megan Huang has 121 relationships.
#
# Matthew Rowland has 823 relationships.
#
# Brian Bautista has 306 relationships.
#
# Kaitlyn Campbell has 965 relationships.
#
# David Wright has 108 relationships.
#
# Joseph Young has 50 relationships.
#
# Michele Williams has 553 relationships.
#
# Mrs. Carol Miller has 985 relationships.
#
# Nicholas Howard has 353 relationships.
#
# Kenneth Webb has 867 relationships.
#
# Jonathan Harris has 993 relationships.
#
# Christina Campos has 456 relationships.
#
# Theresa Hughes has 709 relationships.
#
# Martin Lewis has 125 relationships.
#
# Victoria Young has 435 relationships.
#
# Miss Katherine Pearson has 483 relationships.
#
# Matthew Olson has 451 relationships.
#
# Michael Henry has 575 relationships.
#
# Matthew Olson has 55 relationships.
#
# Lisa Bell has 373 relationships.
#
# Michael Cruz has 210 relationships.
#
# Heather Mcpherson has 960 relationships.
#
# David Stevens has 293 relationships.
#
# Jeffrey Rogers has 710 relationships.
#
# Erica Madden has 815 relationships.
#
# Gerald Leonard has 759 relationships.
#
# Stacey Crane has 691 relationships.
#
# Tiffany Barr has 534 relationships.
#
# Jordan Carr has 914 relationships.
#
# Manuel Gray has 498 relationships.
#
# Erica Miller has 41 relationships.
#
# Antonio Kerr has 412 relationships.
#
# Paul Watson has 445 relationships.
#
# Melvin Park has 374 relationships.
#
# Steven Holmes has 5 relationships.
#
# Rachael Bridges has 231 relationships.
#
# Lisa Steele has 932 relationships.
#
# Joseph Beard has 478 relationships.
#
# Jamie Fisher has 226 relationships.
#
# Rachael Bridges has 251 relationships.
#
# Pamela Sullivan has 740 relationships.
#
# Glenda Wilson has 737 relationships.
#
# Benjamin Curtis has 822 relationships.
#
# Jennifer Hansen has 313 relationships.
#
# Chelsea Johnson has 299 relationships.
#
# Sandra Frey has 325 relationships.
#
# Leah Horn has 393 relationships.
#
# Deborah Harris has 574 relationships.
#
# Robert Cobb has 170 relationships.
#
# Samantha Williams has 559 relationships.
#
# Kevin James has 673 relationships.
#
# Donna Stewart has 636 relationships.
#
# David Wright has 686 relationships.
#
# Kevin James has 622 relationships.
#
# Terry Ward has 968 relationships.
#
# Gary Zimmerman has 922 relationships.
#
# Melissa Escobar has 79 relationships.
#
# Erika Lee has 987 relationships.
#
# Terry Ward has 879 relationships.
#
# Barbara Smith has 429 relationships.
#
# Dr. Nicholas Ortiz MD has 408 relationships.
#
# Tracy Wilson has 345 relationships.
#
# Paul White has 533 relationships.
#
# Susan Jenkins has 258 relationships.
#
# Renee Lam has 643 relationships.
#
# Angelica Moody has 580 relationships.
#
# Elizabeth Oconnor has 543 relationships.
#
# Megan Melendez has 519 relationships.
#
# Martin Jones has 566 relationships.
#
# Jose Wagner has 8 relationships.
#
# Casey Lewis has 540 relationships.
#
# Paula Lucas has 261 relationships.
#
# Jeffrey Bates has 122 relationships.
#
# Amber Fisher has 432 relationships.
#
# Joshua Martinez has 984 relationships.
#
# Kevin Allen has 285 relationships.
#
# Scott Goodwin has 364 relationships.
#
# Joshua Gibson has 739 relationships.
#
# Mark Carter has 978 relationships.
#
# Gary Black has 370 relationships.
#
# Lacey Benson has 356 relationships.
#
# Alan Hamilton has 686 relationships.
#
# Trevor Martin has 793 relationships.
#
# Dennis Maddox has 166 relationships.
#
# Micheal Carr has 969 relationships.
#
# Roger Harris has 778 relationships.
#
# Allison Walker has 143 relationships.
#
# Laura Patterson has 109 relationships.
#
# Patricia Davidson has 161 relationships.
#
# Vanessa Chen has 565 relationships.
#
# Seth Hood has 299 relationships.
#
# Brenda Gonzalez has 566 relationships.
#
# Rachael Spears has 648 relationships.
#
# Glenda Wilson has 55 relationships.
#
# Rebecca Ward has 303 relationships.
#
# Dana Dixon has 258 relationships.
#
# Martin Lewis has 464 relationships.
#
# Miranda Mckinney has 567 relationships.
#
# David Chavez has 796 relationships.
#
# Steven Salazar has 71 relationships.
#
# Stacey Crane has 93 relationships.
#
# Carrie Garcia has 687 relationships.
#
# Benjamin Roberts has 944 relationships.
#
# Lori Morris has 154 relationships.
#
# Brian Kelly has 670 relationships.
#
# David Kirk has 272 relationships.
#
# Megan Moore has 406 relationships.
#
# Miss Katherine Pearson has 432 relationships.
#
# Kevin Owens has 100 relationships.
#
# Joanne Kent has 913 relationships.
#
# Melissa Cook has 435 relationships.
#
# Travis Gordon has 943 relationships.
#
# Steven Pena has 642 relationships.
#
# Gary Zimmerman has 303 relationships.
#
# William Travis has 760 relationships.
#
# Marc Shepherd III has 354 relationships.
#
# Kimberly Reed has 272 relationships.
#
# Donna Foster has 415 relationships.
#
# Lacey Grant has 637 relationships.
#
# Michael Walsh has 382 relationships.
#
# Ashley Payne has 809 relationships.
#
# David Mahoney has 711 relationships.
#
# Richard Brown has 534 relationships.
#
# Ronald Stanton has 306 relationships.
#
# James Anderson has 356 relationships.
#
# Stephanie Thompson has 242 relationships.
#
# Danielle Duran has 891 relationships.
#
# Kyle Cherry Jr. has 772 relationships.
#
# Shannon Collins has 789 relationships.
#
# Michael Spencer has 843 relationships.
#
# Michael Osborne has 531 relationships.
#
# Jessica Wiggins has 865 relationships.
#
# Steven Barrett has 770 relationships.
#
# Matthew Palmer has 50 relationships.
#
# Blake Hess has 692 relationships.
#
# Gabriela Barrera has 746 relationships.
#
# Bryan Erickson has 24 relationships.
#
# Scott Goodwin has 462 relationships.
#
# Richard Taylor has 643 relationships.
#
# Jeffery Johnson has 510 relationships.
#
# Frank Wilson has 101 relationships.
#
# Paul Torres has 273 relationships.
#
# Edward Nichols has 617 relationships.
#
# Nathan Scott has 790 relationships.
#
# David Kirk has 185 relationships.
#
# James Vasquez has 59 relationships.
#
# Sara Gardner has 680 relationships.
#
# James Vasquez has 686 relationships.
#
# Natalie Lee has 807 relationships.
#
# Keith Simmons has 380 relationships.
#
# Mr. Martin Smith DDS has 946 relationships.
#
# Audrey Hartman has 408 relationships.
#
# Ryan Quinn has 691 relationships.
#
# Alexander Welch has 593 relationships.
#
# Jeffery Johnson has 284 relationships.
#
# Kelly Austin has 356 relationships.
#
# Frank Burke has 222 relationships.
#
# Cindy Meyer has 387 relationships.
#
# Zachary Montgomery has 91 relationships.
#
# Michael Hines has 726 relationships.
#
# Joseph Beard has 103 relationships.
#
# Angela Horton has 246 relationships.
#
# Carolyn Wright has 30 relationships.
#
# Deborah Davis has 479 relationships.
#
# Sierra Lewis DDS has 400 relationships.
#
# Vincent Grant has 386 relationships.
#
# Melissa Doyle has 684 relationships.
#
# Nichole Jones has 638 relationships.
#
# Joshua Bruce has 609 relationships.
#
# Melanie Downs has 126 relationships.
#
# Jessica Ward has 381 relationships.
#
# Tracy Gray has 360 relationships.
#
# Rachel Smith has 15 relationships.
#
# Roy Robinson has 165 relationships.
#
# David Chavez has 399 relationships.
#
# Kenneth Allen has 16 relationships.
#
# Victor Barrett has 416 relationships.
#
# Aaron Thomas has 463 relationships.
#
# Patricia Marshall has 789 relationships.
#
# Jennifer Collins has 379 relationships.
#
# Marc Shepherd III has 866 relationships.
#
# Mario Lane Jr. has 848 relationships.
#
# Eric Thomas has 421 relationships.
#
# Ryan Thomas has 229 relationships.
#
# Joseph Harris has 448 relationships.
#
# Kendra Cook has 407 relationships.
#
# Brandi Love has 970 relationships.
#
# Matthew Hall has 106 relationships.
#
# Sierra Lewis DDS has 511 relationships.
#
# Vanessa Chen has 467 relationships.
#
# Jeffery Ramirez has 804 relationships.
#
# Miss Katherine Pearson has 636 relationships.
#
# Stephanie Thompson has 891 relationships.
#
# Guy Olsen has 898 relationships.
#
# Joshua Dudley has 688 relationships.
#
# Melissa Wilson has 726 relationships.
#
# Ryan Fisher has 487 relationships.
#
# Marie Harris has 436 relationships.
#
# James Graham has 645 relationships.
#
# Lisa Steele has 992 relationships.
#
# Blake Strong has 107 relationships.
#
# Timothy Murphy has 679 relationships.
#
# Raymond Stanley has 581 relationships.
#
# Ryan Garrison has 690 relationships.
#
# John Hooper has 768 relationships.
#
# Cynthia Mcclure has 464 relationships.
#
# Daniel Mckenzie has 798 relationships.
#
# Rebecca Murphy has 44 relationships.
#
# Christopher Clark has 380 relationships.
#
# Dawn Murphy has 561 relationships.
#
# David Kirk has 611 relationships.
#
# Michael Peterson has 56 relationships.
#
# James Meyer has 588 relationships.
#
# Kevin Maldonado has 823 relationships.
#
# Mark Dodson has 237 relationships.
#
# Dana Dixon has 689 relationships.
#
# Jessica Johnson has 688 relationships.
#
# Adam Cannon has 190 relationships.
#
# Steven Barrett has 570 relationships.
#
# Paul Chase has 195 relationships.
#
# Andrew Stout has 207 relationships.
#
# Thomas Wheeler has 539 relationships.
#
# Erin Hayes has 306 relationships.
#
# Joshua Martinez has 977 relationships.
#
# Eric Anderson has 999 relationships.
#
# David Brown has 912 relationships.
#
# Jennifer Smith has 118 relationships.
#
# Erik Bean has 918 relationships.
#
# Jaime Patel has 448 relationships.
#
# Kim Montgomery has 704 relationships.
#
# Kim Medina has 202 relationships.
#
# Rachel Friedman has 12 relationships.
#
# Lori Smith has 262 relationships.
#
# Russell Moore has 772 relationships.
#
# Kimberly Jones has 860 relationships.
#
# Cynthia Mcclure has 160 relationships.
#
# Stephanie Rogers has 636 relationships.
#
# Heidi Morris has 741 relationships.
#
# Gerald Thornton has 756 relationships.
#
# Wendy Garcia has 920 relationships.
#
# Joyce Parker has 69 relationships.
#
# Julie Parks has 749 relationships.
#
# Jeremiah Dudley has 71 relationships.
#
# Kevin James has 523 relationships.
#
# Jonathan Hernandez has 943 relationships.
#
# Carol Brown has 739 relationships.
#
# David Hamilton has 719 relationships.
#
# Janice Knight has 912 relationships.
#
# Allison Walker has 21 relationships.
#
# Francisco Smith has 488 relationships.
#
# Robert Johnston has 409 relationships.
#
# Matthew Melton has 108 relationships.
#
# Carrie Garcia has 212 relationships.
#
# Daniel Bailey has 757 relationships.
#
# Jared Perez has 568 relationships.
#
# Cory Howe has 609 relationships.
#
# Bianca Perez has 457 relationships.
#
# Connie Garcia has 992 relationships.
#
# Karen Hopkins has 587 relationships.
#
# Timothy Marshall has 556 relationships.
#
# Tracie Smith has 219 relationships.
#
# Victor Barrett has 374 relationships.
#
# Jason Greene has 994 relationships.
#
# Kayla Beck has 961 relationships.
#
# Daisy Washington has 283 relationships.
#
# Andre Grant has 335 relationships.
#
# Steven Salazar has 728 relationships.
#
# Katie Pierce has 2 relationships.
#
# Angela Kane has 513 relationships.
#
# Brian Jordan has 22 relationships.
#
# Tiffany Washington has 261 relationships.
#
# Emily Marquez has 384 relationships.
#
# David Stewart has 899 relationships.
#
# Ann Hill has 327 relationships.
#
# Casey Garcia has 560 relationships.
#
# Andrew Tran has 768 relationships.
#
# Kevin Lopez has 694 relationships.
#
# Eric Steele has 423 relationships.
#
# Garrett Brown has 552 relationships.
#
# Sarah Faulkner has 103 relationships.
#
# Natalie Farrell has 52 relationships.
#
# Steven Holmes has 201 relationships.
#
# Brian Johnson has 526 relationships.
#
# Dr. Richard Perry has 789 relationships.
#
# Alex Durham has 116 relationships.
#
# Kristin Guzman has 776 relationships.
#
# Christopher Delgado has 61 relationships.
#
# Patricia Grant has 57 relationships.
#
# Joshua Mccann has 6 relationships.
#
# Miss Mary Martin DVM has 911 relationships.
#
# Kathryn Foster has 999 relationships.
#
# Michele Williams has 744 relationships.
#
# Calvin Cook has 903 relationships.
#
# Aaron Lamb has 568 relationships.
#
# Erica Madden has 184 relationships.
#
# Anne Mitchell has 504 relationships.
#
# Kyle Russo has 178 relationships.
#
# Tammy Mack has 357 relationships.
#
# Justin Miller has 987 relationships.
#
# Natasha Alexander has 467 relationships.
#
# Paul Graves has 502 relationships.
#
# Kiara Taylor has 742 relationships.
#
# Jessica Allen has 523 relationships.
#
# Dr. Richard Perry has 101 relationships.
#
# Robert Acevedo has 651 relationships.
#
# Shannon Case has 256 relationships.
#
# Deanna Wright has 200 relationships.
#
# Heather Reed has 184 relationships.
#
# Laura Johnson has 476 relationships.
#
# Terry Harrington has 657 relationships.
#
# David Hamilton has 171 relationships.
#
# Stephanie Thompson has 93 relationships.
#
# Kristin Guzman has 150 relationships.
#
# Rachel Harmon has 392 relationships.
#
# Cory Ross has 698 relationships.
#
# Thomas Wheeler has 245 relationships.
#
# Nichole Jones has 836 relationships.
#
# Jason Greene has 619 relationships.
#
# Michael Spencer has 330 relationships.
#
# Mr. Roberto Rogers has 387 relationships.
#
# Vanessa Chen has 245 relationships.
#
# Brandi Ruiz has 595 relationships.
#
# Logan Deleon has 694 relationships.
#
# Stephanie Ayala has 81 relationships.
#
# Scott Goodwin has 935 relationships.
#
# George Miller has 704 relationships.
#
# Miguel Harrison has 930 relationships.
#
# Madison Johnson has 449 relationships.
#
# Carolyn Wright has 81 relationships.
#
# Abigail Cisneros has 35 relationships.
#
# Alexandra Lambert has 275 relationships.
#
# Angela Nguyen has 357 relationships.
#
# Adam Cannon has 953 relationships.
#
# Lindsey Smith has 998 relationships.
#
# Russell Moore has 935 relationships.
#
# Travis Gordon has 720 relationships.
#
# Paula Lucas has 219 relationships.
#
# Cynthia Mcclure has 23 relationships.
#
# Jonathan Harper has 17 relationships.
#
# Deborah Reyes has 142 relationships.
#
# Nichole Griffith has 203 relationships.
#
# Steven Barrett has 991 relationships.
#
# Erin Williams has 570 relationships.
#
# Robert Atkinson has 823 relationships.
#
# Angela Hill has 195 relationships.
#
# Christopher Jackson has 158 relationships.
#
# Scott Goodwin has 586 relationships.
#
# Lisa George has 769 relationships.
#
# Jaime Forbes has 821 relationships.
#
# Sarah Allen has 63 relationships.
#
# David Stewart has 440 relationships.
#
# Matthew Dillon has 819 relationships.
#
# Heidi Frey has 890 relationships.
#
# Melanie Downs has 217 relationships.
#
# Richard Powell has 364 relationships.
#
# Alex Durham has 745 relationships.
#
# Samantha Kelley has 607 relationships.
#
# James Riley has 780 relationships.
#
# Jeremy Cook has 114 relationships.
#
# Alyssa Gilmore has 864 relationships.
#
# Roy Robinson has 432 relationships.
#
# John Torres has 642 relationships.
#
# Michael Wallace has 895 relationships.
#
# Jimmy Dixon has 64 relationships.
#
# Patrick Brown has 657 relationships.
#
# Debra Garcia has 764 relationships.
#
# Chelsea Fisher has 113 relationships.
#
# Jaime Patel has 868 relationships.
#
# Rachael Spears has 575 relationships.
#
# Rachel Byrd has 690 relationships.
#
# David Carter has 768 relationships.
#
# Andrew Bell has 517 relationships.
#
# Richard Powell has 822 relationships.
#
# Michael Lewis has 335 relationships.
#
# Alan Huerta has 262 relationships.
#
# Patricia Grant has 300 relationships.
#
# Miranda Mckinney has 554 relationships.
#
# Sandra Garza has 374 relationships.
#
# John Floyd has 323 relationships.
#
# Jason Martin has 803 relationships.
#
# Donald Bradshaw has 751 relationships.
#
# Keith Zavala has 437 relationships.
#
# Ann Hill has 514 relationships.
#
# Kyle Russo has 498 relationships.
#
# Amy Marks has 415 relationships.
#
# Roberto Torres has 493 relationships.
#
# Seth Hood has 48 relationships.
#
# Kristy Smith has 725 relationships.
#
# Michael Taylor has 395 relationships.
#
# Michael Larsen has 655 relationships.
#
# Debbie Tucker has 329 relationships.
#
# Nicholas Jimenez has 123 relationships.
#
# Mark Townsend has 336 relationships.
#
# Timothy Murphy has 422 relationships.
#
# Daniel Mckenzie has 96 relationships.
#
# Patricia Davidson has 385 relationships.
#
# Dana Dixon has 75 relationships.
#
# Anthony Hutchinson has 77 relationships.
#
# Jessica Hartman has 144 relationships.
#
# Randy Lewis has 93 relationships.
#
# Jennifer Smith has 429 relationships.
#
# Russell Moore has 308 relationships.
#
# Vanessa Martinez has 869 relationships.
#
# Jordan Carr has 645 relationships.
#
# Joshua Bruce has 8 relationships.
#
# George Miller has 360 relationships.
#
# Alicia Wright has 263 relationships.
#
# Emily Kennedy has 921 relationships.
#
# Katie Lopez has 774 relationships.
#
# Lawrence Bowers has 471 relationships.
#
# John Scott has 894 relationships.
#
# Stephen Thompson has 347 relationships.
#
# Scott Goodwin has 426 relationships.
#
# Sandra Flores has 643 relationships.
#
# Mr. Martin Smith DDS has 890 relationships.
#
# Lori Smith has 477 relationships.
#
# Paul King has 482 relationships.
#
# Caleb Harris has 813 relationships.
#
# Michael Miller has 965 relationships.
#
# Jonathan Morris has 172 relationships.
#
# Rebekah Smith has 405 relationships.
#
# Melanie Mitchell has 869 relationships.
#
# Matthew Rowland has 356 relationships.
#
# Kevin Morgan has 433 relationships.
#
# Larry Cooper has 399 relationships.
#
# Nancy Foster has 280 relationships.
#
# Robert Reese has 1000 relationships.
#
# Carla Green has 830 relationships.
#
# Mark Carter has 726 relationships.
#
# Andrew Silva has 400 relationships.
#
# Kendra Davis has 715 relationships.
#
# Brian Johnson has 791 relationships.
#
# David Hernandez has 994 relationships.
#
# Dr. John Collins has 326 relationships.
#
# Jason Greene has 615 relationships.
#
# Joy Butler has 611 relationships.
#
# Samantha Potter has 541 relationships.
#
# Stephen Thompson has 696 relationships.
#
# Scott Goodwin has 193 relationships.
#
# Lisa Bell has 456 relationships.
#
# Jessica Bradley has 820 relationships.
#
# Melanie Mitchell has 891 relationships.
#
# Sean Bennett has 691 relationships.
#
# Caitlin Kim has 449 relationships.
#
# Tiffany Kim has 305 relationships.
#
# Rachael White has 13 relationships.
#
# Heather Reed has 856 relationships.
#
# Monica Navarro has 485 relationships.
#
# Sierra Lewis DDS has 378 relationships.
#
# Jason Herrera has 351 relationships.
#
# William Rios has 849 relationships.
#
# Martha Williams has 139 relationships.
#
# Rachel Carter has 293 relationships.
#
# Douglas Hardin has 602 relationships.
#
# Kelsey Kirby has 813 relationships.
#
# Derek Hayes has 876 relationships.
#
# Vanessa Martinez has 723 relationships.
#
# Richard Bell has 313 relationships.
#
# Christine Webster has 499 relationships.
#
# Dawn Mccann has 259 relationships.
#
# Courtney Melendez has 525 relationships.
#
# Heidi Morris has 523 relationships.
#
# Stephanie Jackson has 998 relationships.
#
# Wendy Garcia has 968 relationships.
#
# Kenneth Pratt has 28 relationships.
#
# Tonya Chan has 379 relationships.
#
# Vanessa Chen has 269 relationships.
#
# Michael Miller has 715 relationships.
#
# Michael Lawrence has 748 relationships.
#
# Kimberly Parker has 75 relationships.
#
# Jaime Forbes has 330 relationships.
#
# William Hernandez has 788 relationships.
#
# Renee Lam has 282 relationships.
#
# Daniel Tran has 987 relationships.
#
# Raymond Peters has 529 relationships.
#
# Jonathan Watson has 704 relationships.
#
# Emily Dalton has 251 relationships.
#
# Jeff Suarez has 363 relationships.
#
# Nancy Griffith has 728 relationships.
#
# James Vasquez has 830 relationships.
#
# Mr. David Campbell DDS has 914 relationships.
#
# James Davis has 752 relationships.
#
# Lacey Grant has 52 relationships.
#
# Heidi Morris has 343 relationships.
#
# Sean Boyle has 36 relationships.
#
# Kiara Taylor has 838 relationships.
#
# Jessica Allen has 772 relationships.
#
# Victor Barrett has 775 relationships.
#
# Robert Merritt has 810 relationships.
#
# Scott Carter has 428 relationships.
#
# Alan Hamilton has 769 relationships.
#
# Casey Lewis has 253 relationships.
#
# Hunter Ortega has 869 relationships.
#
# Patrick Brown has 187 relationships.
#
# Cindy Conner has 172 relationships.
#
# Kim Montgomery has 500 relationships.
#
# Lisa Brown has 503 relationships.
#
# Jason Conner has 456 relationships.
#
# Rachel Romero has 554 relationships.
#
# Leah Horn has 930 relationships.
#
# Cameron Chen has 913 relationships.
#
# Dana Dixon has 162 relationships.
#
# Roger Hudson has 643 relationships.
#
# Robert Torres has 747 relationships.
#
# Christopher Murphy has 604 relationships.
#
# Kim Gordon has 517 relationships.
#
# Melissa Doyle has 956 relationships.
#
# Eric Anderson has 334 relationships.
#
# Kelsey Kirby has 671 relationships.
#
# Brent Simmons has 955 relationships.
#
# Nicole Roberts has 978 relationships.
#
# Morgan Oconnor has 725 relationships.
#
# Amanda Novak has 363 relationships.
#
# Douglas Perez has 374 relationships.
#
# Jeff Suarez has 746 relationships.
#
# Steven Pena has 772 relationships.
#
# Erika Lee has 789 relationships.
#
# Jeremy Cook has 524 relationships.
#
# Steven Salazar has 907 relationships.
#
# Natalie Farrell has 396 relationships.
#
# Larry Thompson has 84 relationships.
#
# Carl Blanchard has 655 relationships.
#
# Sandra Garza has 548 relationships.
#
# Rachel Friedman has 966 relationships.
#
# Miss Katherine Pearson has 304 relationships.
#
# Victoria Young has 663 relationships.
#
# Kelly Brown has 232 relationships.
#
# Jonathan Alexander has 28 relationships.
#
# Anthony Holt has 697 relationships.
#
# Frederick Salazar has 720 relationships.
#
# Roberto Torres has 205 relationships.
#
# David Brown has 272 relationships.
#
# Brenda Gonzalez has 623 relationships.
#
# Paul Graves has 504 relationships.
#
# Nicole Watson has 684 relationships.
#
# Erik Kramer has 234 relationships.
#
# Brian Kelly has 701 relationships.
#
# Mary Lewis has 538 relationships.
#
# Diana Golden has 711 relationships.
#
# Scott Hernandez has 922 relationships.
#
# Stacey Crane has 708 relationships.
#
# Chris Nelson has 32 relationships.
#
# Shannon Collins has 965 relationships.
#
# Catherine Harris has 912 relationships.
#
# Russell Moore has 735 relationships.
#
# Jonathan Harris has 881 relationships.
#
# Wendy Henry has 642 relationships.
#
# Kaitlyn Campbell has 134 relationships.
#
# Elizabeth Cohen has 209 relationships.
#
# Kyle Cherry Jr. has 230 relationships.
#
# Derek Hayes has 185 relationships.
#
# Larry Cooper has 668 relationships.
#
# Carlos Ferguson has 756 relationships.
#
# Kim Montgomery has 244 relationships.
#
# Larry Cooper has 759 relationships.
#
# Deanna Wright has 984 relationships.
#
# Amber Brown has 781 relationships.
#
# Lisa Adams has 259 relationships.
#
# Stephanie Ayala has 183 relationships.
#
# Sandra Flores has 368 relationships.
#
# Joshua Green has 715 relationships.
#
# Melissa Stewart has 621 relationships.
#
# Nichole Griffith has 787 relationships.
#
# Christina Campos has 582 relationships.
#
# Donald Wiggins has 164 relationships.
#
# Calvin Cook has 178 relationships.
#
# Antonio Kerr has 117 relationships.
#
# Gabrielle Diaz has 290 relationships.
#
# Rachel Byrd has 559 relationships.
#
# Tracy Carter has 670 relationships.
#
# Matthew Hall has 861 relationships.
#
# Melanie Downs has 194 relationships.
#
# Caleb Meadows has 923 relationships.
#
# Jonathan Harper has 161 relationships.
#
# Christina Colon has 637 relationships.
#
# Mary Martin has 636 relationships.
#
# Stacy Pham has 971 relationships.
#
# Jonathan Stewart has 29 relationships.
#
# Margaret Pruitt has 77 relationships.
#
# Joel Lloyd has 424 relationships.
#
# Melissa Doyle has 831 relationships.
#
# Abigail Barrett has 557 relationships.
#
# Frank Burke has 613 relationships.
#
# Jonathan Morris has 472 relationships.
#
# Donna Stewart has 692 relationships.
#
# Melissa Stewart has 318 relationships.
#
# Zachary Montgomery has 78 relationships.
#
# Joshua Hill has 52 relationships.
#
# Sheena Mclean has 923 relationships.
#
# Erica Castillo has 858 relationships.
#
# Christina Colon has 699 relationships.
#
# Kirsten Mcfarland has 840 relationships.
#
# Danny Kline has 186 relationships.
#
# Donald Bradshaw has 276 relationships.
#
# Angela Kane has 607 relationships.
#
# Marie Sanchez has 386 relationships.
#
# Barbara Cooley has 244 relationships.
#
# Keith Zavala has 863 relationships.
#
# Christopher Guerrero has 7 relationships.
#
# Joshua Gibson has 680 relationships.
#
# Miguel Harrison has 877 relationships.
#
# Stephanie Thompson has 161 relationships.
#
# Christopher Ross has 17 relationships.
#
# Martin Allen has 310 relationships.
#
# Cory Howe has 488 relationships.
#
# Monica Martin has 900 relationships.
#
# Teresa Curtis has 957 relationships.
#
# Jason Greene has 153 relationships.
#
# Gavin Schroeder has 244 relationships.
#
# Alison Evans has 569 relationships.
#
# Richard Mathis has 965 relationships.
#
# Kelly Brown has 2 relationships.
#
# Caleb Mejia has 175 relationships.
#
# Holly Franklin has 580 relationships.
#
# Christopher Baker has 345 relationships.
#
# Jamie Fisher has 805 relationships.
#
# Brittany Miller has 508 relationships.
#
# Rachel Romero has 822 relationships.
#
# John Hooper has 717 relationships.
#
# Blake Strong has 823 relationships.
#
# Bruce Thomas has 493 relationships.
#
# Jason Herrera has 830 relationships.
#
# Robert Acevedo has 363 relationships.
#
# David Stewart has 457 relationships.
#
# Angel Miller has 478 relationships.
#
# Laurie Baker has 823 relationships.
#
# Carol Brown has 749 relationships.
#
# Melanie Mitchell has 845 relationships.
#
# Timothy Marshall has 829 relationships.
#
# Dawn Murphy has 264 relationships.
#
# Erica Morris has 568 relationships.
#
# Justin Miller has 653 relationships.
#
# Noah Ramirez has 832 relationships.
#
# Sierra Smith has 155 relationships.
#
# James Perry has 597 relationships.
#
# Monica Navarro has 284 relationships.
#
# Matthew Hall has 290 relationships.
#
# Joseph Woodard has 593 relationships.
#
# Laurie Baker has 707 relationships.
#
# Alex Strickland has 480 relationships.
#
# Sarah Harris has 564 relationships.
#
# Holly Franklin has 446 relationships.
#
# Jennifer Smith has 849 relationships.
#
# Katie Pierce has 297 relationships.
#
# Kylie Figueroa has 519 relationships.
#
# Brandi Ruiz has 161 relationships.
#
# Douglas Perez has 95 relationships.
#
# Steven Gutierrez has 244 relationships.
#
# Molly Davis has 850 relationships.
#
# Blake Strong has 585 relationships.
#
# Erica Madden has 87 relationships.
#
# Alexis Thomas has 513 relationships.
#
# Blake Strong has 277 relationships.
#
# Rebecca Ward has 984 relationships.
#
# Stephanie Thompson has 834 relationships.
#
# Emily Kennedy has 943 relationships.
#
# Veronica Diaz has 835 relationships.
#
# Evan Montoya has 737 relationships.
#
# Jennifer Rowe has 454 relationships.
#
# Kristy Smith has 839 relationships.
#
# Lindsey Bell has 633 relationships.
#
# Melissa Burns has 811 relationships.
#
# Catherine Weaver has 665 relationships.
#
# Veronica Diaz has 427 relationships.
#
# Christopher Medina has 476 relationships.
#
# Ralph Davis has 797 relationships.
#
# John Chandler has 451 relationships.
#
# Adam Garcia has 266 relationships.
#
# Christopher Kim has 396 relationships.
#
# Logan Sanchez has 525 relationships.
#
# Ronald Potts has 877 relationships.
#
# Andrew Bell has 921 relationships.
#
# Brandon Park has 425 relationships.
#
# Joshua Martinez has 621 relationships.
#
# Adrian Evans has 596 relationships.
#
# Ian Newman has 257 relationships.
#
# James Davis has 601 relationships.
#
# Patrick Robinson has 851 relationships.
#
# Ian Newman has 871 relationships.
#
# Jennifer Hansen has 737 relationships.
#
# Alexis Thomas has 944 relationships.
#
# Brian Richardson has 271 relationships.
#
# Danielle Peterson has 819 relationships.
#
# Alicia Townsend has 792 relationships.
#
# Chad Walker has 599 relationships.
#
# Sarah Harris has 801 relationships.
#
# Justin Johnson has 316 relationships.
#
# David Brown has 501 relationships.
#
# Donald Bradshaw has 94 relationships.
#
# Angela Mcbride has 422 relationships.
#
# Kelsey Kirby has 556 relationships.
#
# James Tucker has 713 relationships.
#
# Ian Newman has 649 relationships.
#
# Catherine Harris has 879 relationships.
#
# Martin Jones has 897 relationships.
#
# Calvin Cook has 58 relationships.
#
# Dr. John Collins has 26 relationships.
#
# Christine Stokes has 284 relationships.
#
# Chelsea Johnson has 145 relationships.
#
# Monica Navarro has 738 relationships.
#
# Heather Fisher has 218 relationships.
#
# Sandra Flores has 549 relationships.
#
# Emily Marquez has 625 relationships.
#
# Sandra Flores has 285 relationships.
#
# William Henderson has 496 relationships.
#
# Candice Rosales has 403 relationships.
#
# Denise Johnston has 268 relationships.
#
# Jennifer Edwards has 615 relationships.
#
# Justin Johnson has 652 relationships.
#
# Eric Collins has 562 relationships.
#
# Mrs. Kaitlyn Hopkins DDS has 117 relationships.
#
# Megan Moore has 668 relationships.
#
# Kristen Charles has 943 relationships.
#
# Deborah Hoffman has 252 relationships.
#
# Tara Foster has 978 relationships.
#
# Isabella Miller has 24 relationships.
#
# Carl Blanchard has 311 relationships.
#
# Margaret Owen has 361 relationships.
#
# Shannon Collins has 725 relationships.
#
# Jessica Ward has 556 relationships.
#
# Andrea Cruz has 210 relationships.
#
# Rebecca Ward has 793 relationships.
#
# Jeffrey Bates has 955 relationships.
#
# Jonathan Martinez has 96 relationships.
#
# Miss Mary Martin DVM has 905 relationships.
#
# Joshua Dudley has 603 relationships.
#
# Paul White has 527 relationships.
#
# Robert White has 838 relationships.
#
# Joshua Dudley has 630 relationships.
#
# Adam Cannon has 213 relationships.
#
# Carly Huff has 29 relationships.
#
# Francisco Smith has 619 relationships.
#
# Stacey Crane has 252 relationships.
#
# Cindy Meyer has 508 relationships.
#
# Benjamin Roberts has 661 relationships.
#
# Alex Strickland has 194 relationships.
#
# Casey Hill has 555 relationships.
#
# Brittany Miller has 311 relationships.
#
# Diana Golden has 736 relationships.
#
# Kylie Figueroa has 179 relationships.
#
# Michael Merritt has 94 relationships.
#
# Kerry Anthony has 669 relationships.
#
# Brandon Cruz has 288 relationships.
#
# Walter Taylor has 490 relationships.
#
# Cindy Tran has 582 relationships.
#
# Jo Wilkinson has 266 relationships.
#
# Colton Espinoza MD has 509 relationships.
#
# William Rios has 239 relationships.
#
# Katie Pierce has 575 relationships.
#
# Beth Morales has 170 relationships.
#
# Ryan Quinn has 937 relationships.
#
# Kristy Smith has 101 relationships.
#
# Mark Thompson has 828 relationships.
#
# Erica Morris has 553 relationships.
#
# Jennifer Edwards has 898 relationships.
#
# Paula Chen has 992 relationships.
#
# Jill Mayer has 425 relationships.
#
# Anne Mitchell has 749 relationships.
#
# Jimmy Dixon has 311 relationships.
#
# Phillip Clay has 882 relationships.
#
# Jonathan Alexander has 378 relationships.
#
# Rebecca Peterson has 44 relationships.
#
# Andrew Ortiz has 377 relationships.
#
# Robert White has 915 relationships.
#
# Haley Rodriguez has 793 relationships.
#
# Chris Nelson has 908 relationships.
#
# Gabriel Brock has 919 relationships.
#
# James Vasquez has 534 relationships.
#
# Eric Steele has 6 relationships.
#
# Larry Thompson has 410 relationships.
#
# Larry Thompson has 409 relationships.
#
# Mr. Martin Smith DDS has 917 relationships.
#
# Rachel Harmon has 180 relationships.
#
# Patrick Brown has 559 relationships.
#
# Tara Foster has 407 relationships.
#
# Eric Miller has 696 relationships.
#
# Gregory Brennan has 134 relationships.
#
# David Carter has 243 relationships.
#
# Laura Johnson has 489 relationships.
#
# Tiffany Barr has 233 relationships.
#
# Angela Horton has 702 relationships.
#
# Scott Haynes has 763 relationships.
#
# Kimberly Jones has 803 relationships.
#
# Randy Wright has 637 relationships.
#
# Chelsea Johnson has 682 relationships.
#
# Erica Castillo has 481 relationships.
#
# Mario Lane Jr. has 986 relationships.
#
# Robert Acevedo has 112 relationships.
#
# Allison Walker has 492 relationships.
#
# Carla Green has 256 relationships.
#
# Stephanie Thompson has 971 relationships.
#
# Martha Williams has 47 relationships.
#
# Jillian Herring has 591 relationships.
#
# Brandon Cruz has 397 relationships.
#
# Robert Acevedo has 335 relationships.
#
# Michael Wallace has 365 relationships.
#
# Matthew Gould has 980 relationships.
#
# Carla Knight has 437 relationships.
#
# Gregory Brennan has 876 relationships.
#
# Lauren Ortiz has 630 relationships.
#
# Abigail Barrett has 53 relationships.
#
# Jenna Zimmerman has 953 relationships.
#
# Ebony Gay has 142 relationships.
#
# Michael Moss has 244 relationships.
#
# Jennifer Rowe has 596 relationships.
#
# David Wright has 614 relationships.
#
# Phillip Clay has 525 relationships.
#
# Nathaniel Bailey has 161 relationships.
#
# Tara Foster has 716 relationships.
#
# Christopher Baker has 295 relationships.
#
# Donald Franklin has 965 relationships.
#
# Kristy Smith has 689 relationships.
#
# Patrick King II has 89 relationships.
#
# Michele David has 630 relationships.
#
# Joseph Woodard has 487 relationships.
#
# Ann Vasquez has 996 relationships.
#
# Amanda Novak has 96 relationships.
#
# Tiffany Washington has 854 relationships.
#
# Karen Hopkins has 233 relationships.
#
# Nancy Foster has 113 relationships.
#
# Michael Lewis has 186 relationships.
#
# Nicole Carrillo has 904 relationships.
#
# Brandi Ruiz has 456 relationships.
#
# Natalie Pennington has 402 relationships.

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
